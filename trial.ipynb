# %%
customers = {
    'customer1':{"name": "Alice", "age": 25, "location": "New York"},
    'customer2':{"name": "Bob", "age": 30, "location": "Los Angeles"},
    'customer3':{"name": "Charlie", "age": 20, "location": "Chicago"}
}
print('customer names: ')
for customer in customers:
  print(f"{customers[customer]['name']} : {customers[customer]['age']}")
# Out:
# customer names:
# Alice : 25
# Bob : 30
# Charlie : 20

# %%
def square(number):
  return number * number
result = square(int(input('Enter number: ')))
print(result)  

result = square(int(input('Enter number: ')))
print(result)
# Out:
# Enter number: 3
# 9
# Enter number: 3
# 9

# %%
numbers = {1,2,3,3,4}
print(numbers)

days=['mon','tue','wed','thurs','thurs']
days.insert(3, 'fri')
print(days)
# Out:
# {1, 2, 3, 4}
# ['mon', 'tue', 'wed', 'fri', 'thurs', 'thurs']
